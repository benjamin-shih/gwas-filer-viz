# %% [markdown]
# # FILER API endpoints in Jupyter
#
# FILER data access API -- 2021-04-13 powerpoint examples

# %%
import urllib.parse
import json, requests, pprint

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #### FILER web API endpoints:
#
# `get_data_region`
#
# `get_metadata`
#
# `get_overlapping_tracks_by_coord`

# %%
request_url_FILER = 'https://tf.lisanwanglab.org/FILER'
request_url_GADB = 'https://tf.lisanwanglab.org/GADB/www'

endpt_data_region = 'get_data_region.php' 
endpt_metadata = 'get_metadata.php'
endpt_overlap_track = 'get_overlapping_tracks_by_coord.php'

# %% [markdown]
# <br>
#
# ### Helper functions

# %%
def get_query_url(requestURL, endpoint):
    return ''.join([requestURL, '/', endpoint, '?'])


def process_request(requestUri, payload=None):
    ''' process request '''
    
    response = requests.get(requestUri, params=payload)
    rjson = None
    
    if response:
        print('Success!')
    else:
        print('An error has occurred:' + str(response.status_code))
    
    try: 
        rjson = response.json()
        print('Response JSON decoded')
    except ValueError:
        print('Error occurred: response JSON decode failed')
        print('response.content =\t', response.content.decode())
    
    return rjson

# %% [markdown]
# <br>
#
# # Accessing individual data tracks in FILER (Web)
#
# 2021 April 13 FILER API ppt slide #5
#
# <div>
# <img src="attachment:8c033777-710d-4364-8ad4-d3916f0bc391.png" width="700"/>
# </div>

# %% [markdown]
# #### get_data_region - example 1:

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_data_region.php'
_params = {
    'region':'chr1:10000-1500000',
    'track':'NGEN000610'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_data_region.php?
# 84
# [{'chr': 'chr1',
#   'end': 780403,
#   'name': 'Peak_1892',
#   'pValue': 1405.68005,
#   'peak': 1193,
#   'qValue': 1402.31372,
#   'score': 133,
#   'signalValue': 62.055,
#   'start': 777957,
#   'strand': '.'},
#  {'chr': 'chr1',
#   'end': 827904,
#   'name': 'Peak_8748',
#   'pValue': 304.29565,
#   'peak': 674,
#   'qValue': 301.79691,
#   'score': 36,
#   'signalValue': 20.25406,
#   'start': 826644,
#   'strand': '.'}]

# %% [markdown]
# #### get_data_region - example 2:

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_data_region.php'
_params = {
    'region':'chr1:10000-900000',
    'track':'NGEN000610', 
    'includeMetadata':1
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_data_region.php?
# 6
# {'Identifier': 'NGEN000610',
#  'features': [{'chr': 'chr1',
#                'end': 780403,
#                'name': 'Peak_1892',
#                'pValue': 1405.68005,
#                'peak': 1193,
#                'qValue': 1402.31372,
#                'score': 133,
#                'signalValue': 62.055,
#                'start': 777957,
#                'strand': '.'},
#               {'chr': 'chr1',
#                'end': 827904,
#                'name': 'Peak_8748',
#                'pValue': 304.29565,
#                'peak': 674,
#                'qValue': 301.79691,
#                'score': 36,
#                'signalValue': 20.25406,
#                'start': 826644,
#                'strand': '.'},
#               {'chr': 'chr1',
#                'end': 877445,
#                'name': 'Peak_48086',
#                'pValue': 6.17021,
#                'peak': 171,
#                'qValue': 4.50416,
#                'score': 10,
#                'signalValue': 2.33937,
#                'start': 876709,
#                'strand': '.'}],
#  'metadata': {'Antibody': 'H3K27ac-human',
#               'Assay': 'ChIP-seq',
#               'Biological replicate(s)': '1, 2',
#               'Biosample type': 'cell line',
#               'Biosamples term id': 'EFO:0002095',
#               'Data Category': 'Called peaks',
#               'Data Source': 'ENCODE',
#               'Date added to GADB': '8/10/2018',
#               'Downloaded date': '6/4/2018',
#               'ENCODE Experiment id': 'ENCSR391NPE',
#               'File format': 'bed narrowPeak',
#               'File name': 'ENCFF014TLB.bed.gz',
#               'File size': 1754467,
#               'Genome build': 'hg38',
#               'Identifier': 'NGEN000610',
#               'Link out URL': 'https://www.encodeproject.org',
#               'Number of intervals': 65292,
#               'Output type': 'peaks',
#               'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/ENCFF014TLB.bed.gz',
#               'Processed file md5': 'd6d8c56fb8bef24d5966aff8f955cad3',
#               'Raw File URL': 'https://www.encodeproject.org/files/ENCFF014TLB/@@download/ENCFF014TLB.bigBed',
#               'Raw file download': 'wget '
#                                    'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF014TLB.bigBed '
#                                    '-P GADB/Annotationtracks/Downloads/ENCODE/',
#               'Raw file md5': 'df81a7b12561452b1a3627983d7beb9b',
#               'Release date': '3/3/2017',
#               'Technical replicate': 'Not reported',
#               'Tissue category': 'Male Reproductive',
#               'bp covered': 101475852,
#               'cell type': '22Rv1',
#               'classification': 'ChIP-seq H3K27ac-histone-mark peaks',
#               'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1',
#               'original cell type name': '22Rv1',
#               'system category': 'Reproductive',
#               'tabix_index Download': 'wget '
#                                       'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/ENCFF014TLB.bed.gz.tbi '
#                                       '-P '
#                                       'GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/',
#               'wget command': 'wget '
#                               'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/ENCFF014TLB.bed.gz '
#                               '-P '
#                               'GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/'},
#  'name': 'NGEN000610',
#  'type': 'bed',
#  'url': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg38/1/ENCFF014TLB.bed.gz'}

# %% [markdown]
# <br>
#
# ## Accessing track metadata

# %% [markdown]
# 2021 April 13 FILER API ppt slide #6
#
# <div>
# <img src="attachment:3be30a25-ccae-45eb-ba3e-809d8e6110ae.png" width="600"/>
# </div>

# %% [markdown]
# #### get_metadata - example 1

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'dataSource':'DASHR2', 
    'tissueCategory':'Connective Tissue'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 48
# [{'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'primary cell',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_annot.bed.gz',
#   'File size': 273634,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000325',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 2599,
#   'Output type': 'annotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_annot.bed.gz',
#   'Processed file md5': '20323f4c41badea9b5e460ffcd1ac1a5',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaks',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_annot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': '50897f7b79756266075aa9e1f04476e8',
#   'Release date': '7/9/2012',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Connective Tissue',
#   'bp covered': 97724,
#   'cell type': 'Articular chondrocyte - knee joint',
#   'classification': 'short total RNA-Seq annotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'articular chondrocyte of knee joint replicate 1',
#   'system category': 'Skeletal',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_annot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_annot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'primary cell',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_unannot.bed.gz',
#   'File size': 2636792,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000326',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 40521,
#   'Output type': 'unannotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_unannot.bed.gz',
#   'Processed file md5': '1cfe6a8fb9b13568eb5a38c43e2f86cb',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaksUnannot',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_unannot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': 'ef08457bfed5c3814331811cab9c7d63',
#   'Release date': '7/9/2012',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Connective Tissue',
#   'bp covered': 833084,
#   'cell type': 'Articular chondrocyte - knee joint',
#   'classification': 'short total RNA-Seq unannotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'articular chondrocyte of knee joint replicate 1',
#   'system category': 'Skeletal',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_unannot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/articular-chondrocyte-of-knee-joint-rep1_ENCSR000CVB_peaks_unannot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'}]

# %% [markdown]
# #### get_metadata - example 2

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'cellType':'IMR-90'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 388
# [{'Antibody': 'Not applicable',
#   'Assay': 'RNA-PET',
#   'Biological replicate(s)': '1, 2',
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0001196',
#   'Data Category': 'Clusters',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000BCT',
#   'File format': 'bed bed12',
#   'File name': 'ENCFF000LGM.bed.gz',
#   'File size': 2625288,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN000048',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 78633,
#   'Output type': 'clusters',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGM.bed.gz',
#   'Processed file md5': 'b22f5eaef445e36851369aada31ce067',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF000LGM/@@download/ENCFF000LGM.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF000LGM.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': '31c25bf88a4a86364baa6cad04ed5026',
#   'Release date': '8/14/2012',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Lung',
#   'bp covered': 3569211053,
#   'cell type': 'IMR-90',
#   'classification': 'RNA-PET clusters',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19',
#   'original cell type name': 'IMR 90',
#   'system category': 'Respiratory',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGM.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGM.bed.gz '
#                   '-P GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'RNA-PET',
#   'Biological replicate(s)': '1, 2',
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0001196',
#   'Data Category': 'Clusters',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000BCZ',
#   'File format': 'bed bed12',
#   'File name': 'ENCFF000LGY.bed.gz',
#   'File size': 3392052,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN000049',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 102150,
#   'Output type': 'clusters',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGY.bed.gz',
#   'Processed file md5': '9bb4ebf0c7bf6196c543375b55e05bc7',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF000LGY/@@download/ENCFF000LGY.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF000LGY.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': '800b0a023cfa53d7af73148784a51b1c',
#   'Release date': '8/14/2012',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Lung',
#   'bp covered': 4589001952,
#   'cell type': 'IMR-90',
#   'classification': 'RNA-PET clusters',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19',
#   'original cell type name': 'IMR 90',
#   'system category': 'Respiratory',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGY.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/ENCFF000LGY.bed.gz '
#                   '-P GADB/Annotationtracks/ENCODE/data/RNA-PET/bed12/hg19/'}]

# %% [markdown]
# #### get_metadata - example 3

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'assayType':'DNase-seq'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 1785
# [{'Antibody': 'Not applicable',
#   'Assay': 'DNase-seq',
#   'Biological replicate(s)': 1,
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0005713',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000EID',
#   'File format': 'bed narrowPeak',
#   'File name': 'ENCFF237NQC.bed.gz',
#   'File size': 1412420,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN004055',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 144749,
#   'Output type': 'peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz',
#   'Processed file md5': '5691284a892227cb4d024b6b583dc934',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF237NQC/@@download/ENCFF237NQC.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF237NQC.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': '1c1ecd5f4fb68e6404e870473f1f8148',
#   'Release date': '4/19/2011',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Liver',
#   'bp covered': 21683857,
#   'cell type': '8988T',
#   'classification': 'DNase-seq peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19',
#   'original cell type name': '8988T',
#   'system category': 'Digestive',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'DNase-seq',
#   'Biological replicate(s)': 1,
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0005713',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000EID',
#   'File format': 'bed broadPeak',
#   'File name': 'ENCFF729HDN.bed.gz',
#   'File size': 1851989,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN011624',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 116678,
#   'Output type': 'hotspots',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz',
#   'Processed file md5': 'a166e3ae14370dddc729aab32fa6cf6f',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF729HDN/@@download/ENCFF729HDN.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF729HDN.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': 'ec9d307083742dc68841ee95cffbc5bd',
#   'Release date': '4/19/2011',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Liver',
#   'bp covered': 41574526,
#   'cell type': '8988T',
#   'classification': 'DNase-seq hotspots',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19',
#   'original cell type name': '8988T',
#   'system category': 'Digestive',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/'}]

# %% [markdown]
# #### get_metadata - example 4

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'dataSource':'ROADMAP', 
    'assayType':'ChIP-seq'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 4800
# [{'Antibody': 'consolidated',
#   'Assay': 'ChIP-seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Genomic annotation',
#   'Data Source': 'ROADMAP',
#   'Date added to GADB': '8/25/2018',
#   'Downloaded date': '8/15/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed4',
#   'File name': 'E114_15_coreMarks_mnemonics.bed.gz',
#   'File size': 2685062,
#   'Genome build': 'hg19',
#   'Identifier': 'NGRM005136',
#   'Link out URL': 'http://www.roadmapepigenomics.org/',
#   'Number of intervals': 464406,
#   'Output type': 'ChromHMM',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19/E114_15_coreMarks_mnemonics.bed.gz',
#   'Processed file md5': '5420560442f55c16af53adee779335a7',
#   'Raw File URL': 'https://egg2.wustl.edu/roadmap/data/byFileType/chromhmmSegmentations/ChmmModels/coreMarks/jointModel/final/all.mnemonics.bedFiles.tgz',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ROADMAP/ChromHMM/E114_15_coreMarks_mnemonics.bed.gz '
#                        '-P GADB/Annotationtracks/Downloads/ROADMAP/ChromHMM/',
#   'Raw file md5': 'aa2593297c6a204e246dfa9d048264c3',
#   'Release date': '10/11/2013',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Lung',
#   'bp covered': 3095691400,
#   'cell type': 'A549',
#   'classification': 'ChIP-seq consolidated ChromHMM',
#   'filepath': '/project/wang4/GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19',
#   'original cell type name': 'A549 EtOH 0.02pct Lung Carcinoma Cell Line',
#   'system category': 'Respiratory',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19/E114_15_coreMarks_mnemonics.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19/E114_15_coreMarks_mnemonics.bed.gz '
#                   '-P GADB/Annotationtracks/RoadMap/ChIP-seq/bed4/hg19/'},
#  {'Antibody': 'H3K27me3',
#   'Assay': 'ChIP-seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'primary culture',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ROADMAP',
#   'Date added to GADB': '8/25/2018',
#   'Downloaded date': '8/15/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed broadPeak',
#   'File name': 'BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.bed.gz',
#   'File size': 7609648,
#   'Genome build': 'hg19',
#   'Identifier': 'NGRM000001',
#   'Link out URL': 'http://www.roadmapepigenomics.org/',
#   'Number of intervals': 314335,
#   'Output type': 'peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1/BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.bed.gz',
#   'Processed file md5': '3874c7861c2d8a216beb6e5ccd925373',
#   'Raw File URL': 'https://egg2.wustl.edu/roadmap/data/byFileType/peaks/unconsolidated/broadPeak/BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.gz',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ROADMAP/broadpeak/BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.gz '
#                        '-P GADB/Annotationtracks/Downloads/ROADMAP/broadpeak/',
#   'Raw file md5': '83081311e03816f3f378c2ce0322fd12',
#   'Release date': '2/8/2015',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Stem Cell',
#   'bp covered': 638569711,
#   'cell type': 'Adipose derived mesenchymal stem cell cultured cell',
#   'classification': 'ChIP-seq H3K27me3-histone-mark peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1',
#   'original cell type name': 'Adipose Derived Mesenchymal Stem Cell Cultured '
#                              'Cells',
#   'system category': 'Stem Cell',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1/BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1/BI.Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells.H3K27me3.1.broadPeak.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/RoadMap/ChIP-seq/broadpeak/hg19/1/'}]

# %% [markdown]
# <br>
#
# 2021 April 13 FILER API ppt slide #7
#
# <div>
# <img src="attachment:3086a2cf-1554-46f9-9bba-b5aee4461e1b.png" width="600"/>
# </div>

# %% [markdown]
# #### get_metadata - example 5:

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'filterString':'."Data Source"=="DASHR2"' 
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 632
# [{'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'immortalized cell line',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'A375-rep1_ENCSR376XXO_peaks_annot.bed.gz',
#   'File size': 276558,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000305',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 2613,
#   'Output type': 'annotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz',
#   'Processed file md5': 'afc1f3ce10dc2487c6b256b8f8b34cf5',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaks',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': 'd95c2513b2c5ef7317bc4fad64a48df9',
#   'Release date': '11/20/2014',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Epithelial',
#   'bp covered': 103970,
#   'cell type': 'A375',
#   'classification': 'short total RNA-Seq annotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'A375 (melanoma cell line) replicate 1',
#   'system category': 'Integumentary',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'immortalized cell line',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz',
#   'File size': 1453643,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000306',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 20625,
#   'Output type': 'unannotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz',
#   'Processed file md5': '7d9be50f4349aa7c7035b26198a8eb43',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaksUnannot',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': 'aaaf1e1dcd5462174a42e4cd08e36c89',
#   'Release date': '11/20/2014',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Epithelial',
#   'bp covered': 444946,
#   'cell type': 'A375',
#   'classification': 'short total RNA-Seq unannotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'A375 (melanoma cell line) replicate 1',
#   'system category': 'Integumentary',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'}]

# %% [markdown]
# #### get_metadata - example 6:

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'filterString':'.Identifier=="NGEN006898"' 
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 1
# [{'Antibody': 'H3K27ac-human',
#   'Assay': 'ChIP-seq',
#   'Biological replicate(s)': '1, 2',
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0002095',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR391NPE',
#   'File format': 'bed narrowPeak',
#   'File name': 'ENCFF422DXB.bed.gz',
#   'File size': 1292904,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN006898',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 45976,
#   'Output type': 'replicated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1/ENCFF422DXB.bed.gz',
#   'Processed file md5': 'abe390cc298fb0ec736a15571f96df63',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF422DXB/@@download/ENCFF422DXB.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF422DXB.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': '42609d68e430821db29e51803521e672',
#   'Release date': '3/3/2017',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Male Reproductive',
#   'bp covered': 90960214,
#   'cell type': '22Rv1',
#   'classification': 'ChIP-seq H3K27ac-histone-mark replicated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1',
#   'original cell type name': '22Rv1',
#   'system category': 'Reproductive',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1/ENCFF422DXB.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1/ENCFF422DXB.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/ENCODE/data/ChIP-seq/narrowpeak/hg19/1/'}]

# %% [markdown]
# #### get_metadata - example 7:

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_metadata.php'
_params = {
    'genomeBuild':'hg19', 
    'filterString':'."File name" | contains("ENCSR376XXO")' 
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_metadata.php?
# 4
# [{'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'immortalized cell line',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'A375-rep1_ENCSR376XXO_peaks_annot.bed.gz',
#   'File size': 276558,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000305',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 2613,
#   'Output type': 'annotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz',
#   'Processed file md5': 'afc1f3ce10dc2487c6b256b8f8b34cf5',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaks',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': 'd95c2513b2c5ef7317bc4fad64a48df9',
#   'Release date': '11/20/2014',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Epithelial',
#   'bp covered': 103970,
#   'cell type': 'A375',
#   'classification': 'short total RNA-Seq annotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'A375 (melanoma cell line) replicate 1',
#   'system category': 'Integumentary',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_annot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'short total RNA-Seq',
#   'Biological replicate(s)': 'Not applicable',
#   'Biosample type': 'immortalized cell line',
#   'Biosamples term id': 'Not applicable',
#   'Data Category': 'Called peaks',
#   'Data Source': 'DASHR2',
#   'Date added to GADB': '7/1/2018',
#   'Downloaded date': '6/30/2018',
#   'ENCODE Experiment id': 'Not applicable',
#   'File format': 'bed bed6+DASHR',
#   'File name': 'A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz',
#   'File size': 1453643,
#   'Genome build': 'hg19',
#   'Identifier': 'NGDS000306',
#   'Link out URL': 'http://dashr2.lisanwanglab.org/index.php',
#   'Number of intervals': 20625,
#   'Output type': 'unannotated peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz',
#   'Processed file md5': '7d9be50f4349aa7c7035b26198a8eb43',
#   'Raw File URL': 'http://dashr2.lisanwanglab.org/table2csv.php?dataSourceDownload=ENCODE_dataportal_hg19&table=peaksUnannot',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed '
#                        '-P '
#                        'GADB/Annotationtracks/Downloads/DASHR/ENCODE_dataportal_hg19/',
#   'Raw file md5': 'aaaf1e1dcd5462174a42e4cd08e36c89',
#   'Release date': '11/20/2014',
#   'Technical replicate': 'Not applicable',
#   'Tissue category': 'Epithelial',
#   'bp covered': 444946,
#   'cell type': 'A375',
#   'classification': 'short total RNA-Seq unannotated peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19',
#   'original cell type name': 'A375 (melanoma cell line) replicate 1',
#   'system category': 'Integumentary',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/A375-rep1_ENCSR376XXO_peaks_unannot.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/DASHRv2/short_total_RNA-seq/hg19/ENCODE_dataportal_hg19/'}]

# %% [markdown]
# <br>
#
# <br>
#
# ## Accessing overlapping tracks / metadata

# %% [markdown]
# <br>
#
# 2021 April 13 FILER API ppt slide #8
#
# <div>
# <img src="attachment:d981c220-d483-4db7-9332-84d145573a25.png" width="600"/>
# </div>

# %% [markdown]
# #### get_overlapping_tracks_by_coord - example 1

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_overlapping_tracks_by_coord.php'
_params = {
    'region':'chr1:1300000-1400000', 
    'genomeBuild':'hg19', 
    'outputFormat':'json', 
    'filterString':'.metadata."Data source"=="DASHR2"' 
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_overlapping_tracks_by_coord.php?
# 0
# []

# %% [markdown]
# <br>
#
# 2021 April 13 FILER API ppt slide #9
#
# <div>
# <img src="attachment:aa8eb0f1-2d5d-4e7f-af19-911be13bb360.png" width="600"/>
# </div>

# %% [markdown]
# #### get_overlapping_tracks_by_coord - example 2

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_overlapping_tracks_by_coord.php'
_params = {
    'region':'chr1:1400000-1500000', 
    'genomeBuild':'hg19', 
    'outputFormat':'json', 
    'filterString':'.metadata."Data source" =="DASHR2" and .metadata."Tissue category"=="Lung"' 
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_overlapping_tracks_by_coord.php?
# 0
# []

# %% [markdown]
# #### get_overlapping_tracks_by_coord - example 3

# %%
requestURL = 'https://tf.lisanwanglab.org/FILER'
endpt = 'get_overlapping_tracks_by_coord.php'
_params = {
    'genomeBuild':'hg19', 
    'region':'chr1:1103243-1103243', 
    'filterString':'.', 
    'outputFormat':'json'
}


## get endpoint URL
_url_endpoint = get_query_url(requestURL, endpt)

## process request
rjson = process_request(_url_endpoint, _params)



print(_url_endpoint)
print(len(rjson))
if isinstance(rjson, list):
    pprint.pprint(rjson[:2])
else:
    pprint.pprint(rjson)
# Out:
# Success!
# Response JSON decoded
# https://tf.lisanwanglab.org/FILER/get_overlapping_tracks_by_coord.php?
# 1859
# [{'Antibody': 'Not applicable',
#   'Assay': 'DNase-seq',
#   'Biological replicate(s)': 1,
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0005713',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000EID',
#   'File format': 'bed narrowPeak',
#   'File name': 'ENCFF237NQC.bed.gz',
#   'File size': 1412420,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN004055',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 144749,
#   'Output type': 'peaks',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz',
#   'Processed file md5': '5691284a892227cb4d024b6b583dc934',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF237NQC/@@download/ENCFF237NQC.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF237NQC.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': '1c1ecd5f4fb68e6404e870473f1f8148',
#   'Release date': '4/19/2011',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Liver',
#   'bp covered': 21683857,
#   'cell type': '8988T',
#   'classification': 'DNase-seq peaks',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19',
#   'original cell type name': '8988T',
#   'system category': 'Digestive',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/ENCFF237NQC.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/ENCODE/data/DNase-seq/narrowpeak/hg19/'},
#  {'Antibody': 'Not applicable',
#   'Assay': 'DNase-seq',
#   'Biological replicate(s)': 1,
#   'Biosample type': 'cell line',
#   'Biosamples term id': 'EFO:0005713',
#   'Data Category': 'Called peaks',
#   'Data Source': 'ENCODE',
#   'Date added to GADB': '8/10/2018',
#   'Downloaded date': '6/4/2018',
#   'ENCODE Experiment id': 'ENCSR000EID',
#   'File format': 'bed broadPeak',
#   'File name': 'ENCFF729HDN.bed.gz',
#   'File size': 1851989,
#   'Genome build': 'hg19',
#   'Identifier': 'NGEN011624',
#   'Link out URL': 'https://www.encodeproject.org',
#   'Number of intervals': 116678,
#   'Output type': 'hotspots',
#   'Processed File Download URL': 'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz',
#   'Processed file md5': 'a166e3ae14370dddc729aab32fa6cf6f',
#   'Raw File URL': 'https://www.encodeproject.org/files/ENCFF729HDN/@@download/ENCFF729HDN.bigBed',
#   'Raw file download': 'wget '
#                        'https://tf.lisanwanglab.org/GADB/Annotationtracks/Downloads/ENCODE/ENCFF729HDN.bigBed '
#                        '-P GADB/Annotationtracks/Downloads/ENCODE/',
#   'Raw file md5': 'ec9d307083742dc68841ee95cffbc5bd',
#   'Release date': '4/19/2011',
#   'Technical replicate': 'Not reported',
#   'Tissue category': 'Liver',
#   'bp covered': 41574526,
#   'cell type': '8988T',
#   'classification': 'DNase-seq hotspots',
#   'filepath': '/project/wang4/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19',
#   'original cell type name': '8988T',
#   'system category': 'Digestive',
#   'tabix_index Download': 'wget '
#                           'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz.tbi '
#                           '-P '
#                           'GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/',
#   'wget command': 'wget '
#                   'https://tf.lisanwanglab.org/GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/ENCFF729HDN.bed.gz '
#                   '-P '
#                   'GADB/Annotationtracks/ENCODE/data/DNase-seq/broadpeak/hg19/'}]
